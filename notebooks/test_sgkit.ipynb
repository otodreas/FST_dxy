# %% [markdown]
# # Exploratory analysis

# %%
# IMPORT LIBRARIES
import sgkit as sg
import xarray as xr
import numpy as np

# %% [markdown]
# ## Using my test data
# `test/ProjTaxaFilt.vcz`

# %%
# LOAD AND PREPARE DATA

# Load data into an xarray.Dataset object
ds = sg.load_dataset("../test/ProjTaxaFilt.vcz")

# Map population structure onto the dimension `sample_cohort`
ds["sample_cohort"] = xr.DataArray(np.array([0] * 5 + [1] * 5 + [2] * 5), dims="samples")

# Create 1-D numpy.array equivalent to the `CHROM` column in the VCF
chrom = ds.contig_id.values[ds.variant_contig.values]

# Assign boolean masks for each chromosome to use to split the dataset by chromosome index
chr5 = chrom == "chr5"
chrz = np.invert(chr5)

# Create two datasets that are subsets of the original by chromosome
ds_chr5 = ds.isel(variants=chr5)
ds_chrz = ds.isel(variants=chrz)

# Remove the original dataset to save memory capacity
del(ds)

# %%
# COMPUTE STATS

# Compute stats for each dataset
for ds in (ds_chr5, ds_chrz):

    # Produce windows
    ds = sg.window_by_variant(ds, size=80)

    # Compute FST and dxy (both are computed with the `sg.Fst` method)
    stats = sg.Fst(ds)

    # print(stats.stat_Fst.values)
    # print(stats.stat_divergence.values)
    # print(np.unique(np.isnan(stats.stat_Fst.values), return_counts=True))
